# %% [markdown]
# # U.S. Medical Insurance Costs-- Step7 Models Comparison & Business Insights

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

# %%
# Build Comparison Table:
comparison_table = pd.DataFrame({
    "model": [
        "OLS Regression",
        "Log-Linear Regression",
        "Random Forest"
    ],
    "R-squared": [
        0.750,
        0.762,
        0.873
    ],
    "MAE": [
        4181.335,
        4227.538,
        2703.819
    ],
    "RMSE": [
        6058.642,
        8281.830,
        4839.950
    ],
    "Interpretability": [
        "High",
        "High",
        "Low"
    ]
})

comparison_table
# Out:
#                    model  R-squared       MAE      RMSE Interpretability
# 0         OLS Regression      0.750  4181.335  6058.642             High
# 1  Log-Linear Regression      0.762  4227.538  8281.830             High
# 2          Random Forest      0.873  2703.819  4839.950              Low

# %%
# Data Visualization
models =[
    "OLS Regression",
    "Log-Linear Regression",
    "Random Forest"
    ]
r2_scores = [
        0.750,
        0.762,
        0.873
]

plt.figure(figsize=(8,5))
plt.bar(models, r2_scores)

plt.title("Model Performance Comparison")
plt.ylabel("R-squared")
plt.ylim([0,1])

plt.savefig("/Users/shenkong/Desktop/Projects/pj02_US_Medical_Insurance_Costs/images/Model_Performance_Comparison.png")
plt.show()
plt.clf()

# %%
# Conclusion:
# The Random Forest model achieved the highest R-squared value (0.873), outperforming both the OLS and log-linear regression models, suggesting the presence of important nonlinear relationships in insurance costs. While Random Forest provided the strongest predictive performance, the linear models remained more interpretable for explaining the effects of smoking, age, and BMI.
